# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/101.7 MB 442.1 kB/s eta 0:03:49
#    ---------------------------------------- 0.8/101.7 MB 559.5 kB/s eta 0:03:01
#    ---------------------------------------- 0.8/101.7 MB 559.5 kB/s eta 0:03:01
#    ---------------------------------------- 1.0/101.7 MB 559.3 kB/s eta 0:03:00
#    ---------------------------------------- 1.0/101.7 MB 559.3 kB/s eta 0:03:00
# ...

# %%
from xgboost import XGBRFRegressor,XGBClassifier
import pandas as pd

# %%
df=pd.read_csv('adult.csv',engine='python',on_bad_lines='skip')
df.head()
# Out:
#    age workclass  fnlwgt  ... hours.per.week  native.country income
# 0   90         ?   77053  ...             40   United-States  <=50K
# 1   82   Private  132870  ...             18   United-States  <=50K
# 2   66         ?  186061  ...             40   United-States  <=50K
# 3   54   Private  140359  ...             40   United-States  <=50K
# 4   41   Private  264663  ...             40   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28442 entries, 0 to 28441
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             28442 non-null  int64
#  1   workclass       28442 non-null  object
#  2   fnlwgt          28442 non-null  int64
#  3   education       28442 non-null  object
#  4   education.num   28442 non-null  int64
#  5   marital.status  28442 non-null  object
#  6   occupation      28442 non-null  object
#  7   relationship    28442 non-null  object
#  8   race            28442 non-null  object
#  9   sex             28442 non-null  object
#  10  capital.gain    28442 non-null  int64
#  11  capital.loss    28442 non-null  int64
#  12  hours.per.week  28442 non-null  int64
#  13  native.country  28442 non-null  object
#  14  income          28442 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.3+ MB

# %%
df['capital.gain'].unique()
# Out:
# array([    0, 99999, 41310, 34095, 27828, 25236, 25124, 22040, 20051,
#        18481, 15831, 15024, 15020, 14344, 14084, 13550, 11678, 10605,
#        10566, 10520,  9562,  9386,  8614,  7978,  7896,  7688,  7443,
#         7430,  7298,  6849,  6767,  6723,  6514,  6497,  6418,  6360,
#         6097,  5721,  5556,  5455,  5178,  5060,  5013,  4934,  4931,
#         4865,  4787,  4687,  4650,  4508,  4416,  4386,  4101,  4064,
#         3942,  3908,  3887,  3818,  3781,  3674,  3471,  3464,  3456,
#         3432,  3418,  3411,  3325,  3273,  3137,  3103,  2993,  2977,
#         2964,  2961,  2936,  2907,  2885,  2829,  2653,  2635,  2597,
#         2580,  2538,  2463,  2414,  2407,  2387,  2354,  2346,  2329,
#         2290,  2228,  2202,  2176,  2174,  2105,  2062,  2050,  2036,
#         2009,  1848,  1831,  1797,  1639,  1506,  1471,  1455,  1424,
#         1409,  1173,  1151,  1111,  1086,  1055,   991,   914,   594,
#          401,   114], dtype=int64)

# %%
df['workclass']=df['workclass'].replace("?",'NA')
df['occupation']=df['occupation'].replace("?","Unknown")

# %%
df['occupation'].unique()
# Out:
# array(['Unknown', 'Exec-managerial', 'Machine-op-inspct',
#        'Prof-specialty', 'Other-service', 'Adm-clerical', 'Craft-repair',
#        'Transport-moving', 'Handlers-cleaners', 'Sales',
#        'Farming-fishing', 'Tech-support', 'Protective-serv',
#        'Armed-Forces', 'Priv-house-serv'], dtype=object)

# %%
model=XGBClassifier()
